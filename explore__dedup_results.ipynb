# %%
import pandas as pd

# %%
pd.set_option("max_colwidth", None)

# %%
df = pd.read_csv('csv_example_output.csv')
df[['Cluster ID','confidence_score','Site name','Address','Zip','Phone']].head(10)
# Out:
#    Cluster ID  confidence_score  \
# 0           0          0.963386
# 1           0          0.963386
# 2           9          0.755361
# 3           9          0.755361
# 4          10          0.766560
# 5          10          0.766560
# 6          11          0.889324
# 7          11          0.889324
# 8          15          0.995987
# 9          17          0.998559
#
#                                                                    Site name  \
# 0                                   Salvation Army - Temple / Salvation Army
# 1                                   Salvation Army - Temple / Salvation Army
# 2             National Louis University - Dr. Effie O. Ellis Training Center
# 3             National Louis University - Dr. Effie O. Ellis Training Center
# 4             Board Trustees-City Colleges of Chicago - Olive-Harvey College
# 5             Board Trustees-City Colleges of Chicago - Olive-Harvey College
# ...

# %%
original = pd.read_csv('csv_example_messy_input.csv')
original[['Site name','Address','Zip','Phone']].head(10)
# Out:
#                                                                    Site name  \
# 0                                   Salvation Army - Temple / Salvation Army
# 1                                   Salvation Army - Temple / Salvation Army
# 2             National Louis University - Dr. Effie O. Ellis Training Center
# 3             National Louis University - Dr. Effie O. Ellis Training Center
# 4             Board Trustees-City Colleges of Chicago - Olive-Harvey College
# 5             Board Trustees-City Colleges of Chicago - Olive-Harvey College
# 6          Easter Seals Society of Metropolitan Chicago - Gilchrist-Marchman
# 7          Easter Seals Society of Metropolitan Chicago - Gilchrist-Marchman
# 8                    Hull House Association - Uptown Head Start / Hull House
# 9   Hull House Association - Child Dev. Central Office- Hull House CDS-Homes
#
#                  Address  Zip      Phone
# 0         1 N Ogden Ave   NaN  2262649.0
# ...
